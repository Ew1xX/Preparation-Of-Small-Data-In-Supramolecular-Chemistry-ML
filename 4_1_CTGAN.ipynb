# %% [markdown]
# # Importing libraries

# %%
# !pip install ctgan
# Out:
# Collecting ctgan
#   Downloading ctgan-0.10.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm<5,>=4.29 in /usr/local/lib/python3.11/dist-packages (from ctgan) (4.67.1)
# Collecting rdt>=1.11.0 (from ctgan)
#   Downloading rdt-1.13.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.23.3 in /usr/local/lib/python3.11/dist-packages (from ctgan) (1.26.4)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from ctgan) (2.2.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan) (2.5.1+cu121)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->ctgan) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->ctgan) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->ctgan) (2024.2)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.11.0->ctgan) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.11.0->ctgan) (1.6.0)
# Collecting Faker>=17 (from rdt>=1.11.0->ctgan)
#   Downloading Faker-33.3.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->ctgan) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->ctgan) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.11.0->ctgan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.11.0->ctgan) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan) (3.0.2)
# Downloading ctgan-0.10.2-py3-none-any.whl (23 kB)
# Downloading rdt-1.13.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.1 MB/s eta 0:00:00
# Downloading Faker-33.3.1-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 12.2 MB/s eta 0:00:00
# Installing collected packages: Faker, rdt, ctgan
# Successfully installed Faker-33.3.1 ctgan-0.10.2 rdt-1.13.2

# %%
from ctgan import CTGAN

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import random

# %%
import torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing data

# %%
df = pd.read_csv("/content/drive/MyDrive/Files For Project/AtomPairsData.csv")
df = df.drop(["Unnamed: 0"], axis = 1)
df
# Out:
#     304  209  SMR_VSA4  PEOE_VSA6  FpDensityMorgan2  MinEStateIndex  \
# 0     1    0  0.000000   0.465948          0.096990        0.905499
# 1     1    0  0.500000   0.000000          0.070652        0.961411
# 2     1    0  0.500000   0.000000          1.000000        0.920140
# 3     1    0  0.000000   0.203617          0.608696        0.625769
# 4     1    0  0.457509   0.143555          0.060870        0.859423
# 5     1    0  0.000000   0.199692          0.391304        0.909123
# 6     1    0  0.000000   0.066564          0.664596        0.912327
# 7     1    0  0.000000   0.314447          0.815857        0.000000
# 8     1    0  0.500000   0.000000          0.739130        0.708749
# 9     0    0  0.000000   0.251558          0.119565        0.948884
# 10    1    0  0.228754   0.215333          0.608696        0.845697
# 11    0    1  1.000000   0.000000          0.000000        0.943088
# 12    0    1  0.595453   0.000000          0.161491        1.000000
# 13    1    0  0.297727   0.377537          0.510870        0.773448
# 14    1    1  0.000000   0.566205          0.403727        0.772038
# 15    1    0  0.000000   0.704541          0.489603        0.758148
# 16    1    0  0.000000   0.600616          0.355499        0.985717
# 17    1    0  0.000000   1.000000          0.115312        0.986167
# 18    0    0  0.297727   0.143555          0.739130        0.904071
# 19    0    1  0.595453   0.000000          0.161491        1.000000
# 20    1    1  0.000000   0.965790          0.598120        0.846982
#
#     VSA_EState1  fr_NH0  MinAbsEStateIndex  FpDensityMorgan1  VSA_EState9  \
# 0      0.000000     0.0           0.585935          0.070404     0.048112
# 1      0.077888     1.0           0.830920          0.098517     0.666724
# 2      0.000000     0.0           0.650086          0.756356     0.048112
# 3      0.000000     0.0           0.580032          1.000000     0.000000
# 4      0.071555     1.0           0.384046          0.025424     1.000000
# 5      0.000000     0.0           0.601815          0.350282     0.048112
# 6      0.000000     0.0           0.615851          0.610169     0.048112
# 7      1.000000     0.5           0.195552          0.816550     0.047135
# 8      0.000000     0.0           0.186018          0.707627     0.048112
# 9      0.060886     1.0           0.776030          0.171610     0.912318
# 10     0.000000     0.0           0.323907          1.000000     0.048112
# 11     0.074381     1.0           0.750635          0.025424     0.989587
# 12     0.126272     1.0           1.000000          0.192494     0.310308
# 13     0.061754     0.5           0.007341          0.463983     0.176876
# 14     0.064341     0.5           0.001162          0.220339     0.048112
# 15     0.098704     0.5           0.000000          0.355932     0.048112
# 16     0.070736     0.5           0.937417          0.197408     0.048112
# 17     0.071198     0.5           0.939391          0.000000     0.048112
# 18     0.064412     0.5           0.579677          0.805085     0.181133
# 19     0.126272     1.0           1.000000          0.192494     0.310308
# 20     0.374256     0.0           0.329535          0.325699     0.048112
#
#     MaxAbsEStateIndex   Ka_mean
# 0            0.220982  0.000420
# 1            0.027884  0.441126
# 2            0.209927  0.006185
# 3            0.178277  0.004812
# 4            0.049802  0.000000
# 5            0.207721  0.006969
# 6            0.197049  0.001184
# 7            0.880993  0.000138
# 8            0.851055  0.000273
# 9            0.014492  0.156787
# 10           0.171797  0.000233
# 11           0.031544  0.872538
# 12           0.000000  0.015597
# 13           0.922314  0.001126
# 14           0.936457  0.047953
# 15           1.000000  0.000939
# 16           0.016654  0.001126
# 17           0.018216  0.003106
# 18           0.013729  0.001547
# 19           0.000000  1.000000
# 20           0.421311  0.000698

# %%
# Determine categorical columns
categorical_features = ["304", "209", "fr_NH0"]

# %% [markdown]
# # Functions

# %%
def set_seed():
  np.random.seed(42)
  torch.manual_seed(42)
  tf.random.set_seed(42)
  random.seed(42)

# %% [markdown]
# # CTGAN

# %% [markdown]
# ### Model №1

# %%
set_seed()
ctgan = CTGAN(verbose=True)
ctgan.fit(df, categorical_features, epochs = 500)
# Out:
# Gen. (0.10) | Discrim. (-0.35): 100%|██████████| 500/500 [00:48<00:00, 10.41it/s]

# %%
set_seed()
samples = ctgan.sample(100)
samples
# Out:
#     304  209  SMR_VSA4  PEOE_VSA6  FpDensityMorgan2  MinEStateIndex  \
# 0     1    0  0.790971   0.805479          1.010582        1.052777
# 1     1    0  0.803725   0.239083          0.481901        1.068688
# 2     0    0  0.167858   0.034253          0.095822        0.910344
# 3     0    1  0.953686  -0.259110         -0.352468        0.958939
# 4     1    0  0.449243   0.034285          0.459278        0.965190
# ..  ...  ...       ...        ...               ...             ...
# 95    1    0  0.084110   0.803725          0.478539        0.843459
# 96    1    0  0.064575   0.421181          0.651673        1.100579
# 97    1    0  0.912934  -0.012378          1.089695        0.944311
# 98    1    0  0.214193  -0.220906          1.160543        0.892817
# 99    1    0  0.544645   0.020751          0.202466        0.696252
#
#     VSA_EState1  fr_NH0  MinAbsEStateIndex  FpDensityMorgan1  VSA_EState9  \
# 0     -0.137870     0.5          -0.130159          0.345812     0.602610
# 1      0.020351     0.5           0.552816          0.449846     0.291603
# 2     -0.069102     0.0           1.223345          0.621671    -0.267821
# 3      0.078030     1.0           0.541599          0.919681     0.088915
# 4     -0.023171     0.5           0.583394          0.746086    -0.237787
# ..          ...     ...                ...               ...          ...
# 95    -0.143926     0.5           0.989368          0.505215    -0.062031
# 96    -0.024105     0.5           0.695580          0.935855    -0.185470
# 97    -0.055837     0.0           0.822150         -0.054328    -0.102338
# 98    -0.078670     1.0           0.366829          0.514772     0.026353
# 99    -0.158020     1.0          -0.472965          0.697045    -0.015050
#
#     MaxAbsEStateIndex   Ka_mean
# 0            0.372639 -0.087750
# 1            0.131268 -0.156727
# 2            0.314469 -0.078596
# 3            0.700624 -0.461636
# 4            0.958249 -0.086638
# ..                ...       ...
# 95           0.474113 -0.252381
# 96           0.096295 -0.010222
# 97           0.738946  0.104348
# 98          -0.073954 -0.336952
# 99          -0.080934  0.105575
#
# [100 rows x 13 columns]

# %% [markdown]
# Dataset value bounds: from 0 to 1, so let's remove unnecessary values

# %%
samples_cleaned = samples[(samples >= 0) & (samples <= 1)].dropna()
samples_cleaned
# Out:
# Empty DataFrame
# Columns: [304, 209, SMR_VSA4, PEOE_VSA6, FpDensityMorgan2, MinEStateIndex, VSA_EState1, fr_NH0, MinAbsEStateIndex, FpDensityMorgan1, VSA_EState9, MaxAbsEStateIndex, Ka_mean]
# Index: []

# %% [markdown]
# ### Model №2
# Increasing learning rate, generator decat (optimizator's coefficient) and quantity of epochs

# %%
set_seed()
ctgan2 = CTGAN(verbose = True,
               generator_lr = 0.01,
               generator_decay=0.0001)
ctgan2.fit(df, categorical_features, epochs = 1000)
# Out:
# Gen. (0.80) | Discrim. (-0.25): 100%|██████████| 1000/1000 [01:53<00:00,  8.79it/s]

# %%
set_seed()
samples2 = ctgan2.sample(100)
samples2
# Out:
#     304  209  SMR_VSA4  PEOE_VSA6  FpDensityMorgan2  MinEStateIndex  \
# 0     1    0  0.140411  -0.076789          0.605123        0.904890
# 1     1    0  0.013335   0.252786          0.210662        0.711381
# 2     1    0 -0.280980  -0.149703          0.586714        0.702374
# 3     0    1  0.321236   0.052782          0.240440        0.826469
# 4     1    0  0.205056   0.631575          0.426388        0.730860
# ..  ...  ...       ...        ...               ...             ...
# 95    1    0 -0.044678   0.035676          0.686124        0.872264
# 96    1    0  0.080731   0.165613          0.667099        1.015647
# 97    1    0  0.059555  -0.016133          0.765960        0.868559
# 98    1    0 -0.153500   1.061984          0.340703        0.842535
# 99    1    0  0.155626   0.464869          0.558961        0.884942
#
#     VSA_EState1  fr_NH0  MinAbsEStateIndex  FpDensityMorgan1  VSA_EState9  \
# 0      0.024678     0.0           0.275646          0.548886    -0.021992
# 1      0.031640     0.5           0.498675          0.621286    -0.086994
# 42           0.559015  0.074192
# 52           0.068225  0.017817
# 63           0.091623  0.126475
# 65           0.186138  0.050561
# 66           0.896720  0.121016
# 73           0.073615  0.064457
# 79           0.320499  0.051131
# 84           0.187338  0.098887
# 93           0.001609  0.071058

# %%
samples_cleaned.shape, samples_cleaned2.shape
# Out:
# ((0, 13), (14, 13))

# %% [markdown]
# The quantity and quality of values has increased!

# %% [markdown]
# ### Model №3
# Increasing learning rate and generator decat (optimizator's coefficient)

# %%
ctgan3 = CTGAN(verbose = True,
               generator_lr = 0.1,
               generator_decay=0.001)
ctgan3.fit(df, categorical_features, epochs = 1000)
# Out:
# Gen. (3.64) | Discrim. (-3.01): 100%|██████████| 1000/1000 [02:29<00:00,  6.70it/s]

# %%
samples3 = ctgan3.sample(100)
samples3
# Out:
#     304  209  SMR_VSA4  PEOE_VSA6  FpDensityMorgan2  MinEStateIndex  \
# 0     0    0  0.252397  -0.781723          1.562825        0.463312
# 1     1    0  0.572936   0.787433          1.562853        0.463312
# 2     1    0 -0.561389   0.788607          1.562649        1.171115
# 3     1    0 -0.478855   0.788610          1.093436        1.302402
# 4     1    0  1.493385   0.786628          0.616185        1.302402
# ..  ...  ...       ...        ...               ...             ...
# 95    1    0 -0.478854   0.788610         -0.708476        1.302394
# 96    0    0 -0.478855   1.830334          1.562850        0.463455
# 97    1    0 -0.562163  -0.508663          1.562031        1.302319
# 98    0    0  1.493385  -0.509437         -0.733177        1.254121
# 99    1    1  1.493384  -0.782248         -0.733145        1.301528
#
#     VSA_EState1  fr_NH0  MinAbsEStateIndex  FpDensityMorgan1  VSA_EState9  \
# 0     -0.210958     0.0          -0.721657         -0.038794    -0.406667
# 1     -0.210958     0.5          -0.115063          1.801133    -0.408873
# 2     -0.210958     0.5           1.826292          0.875284    -0.408852
# 3     -0.187117     0.0           1.826305         -0.488254    -0.408864
# 4      0.215638     1.0           1.826285          1.801092     0.570109
# ..          ...     ...                ...               ...          ...
# 95    -0.111720     0.0          -0.729015          1.713560    -0.408872
# 96     0.318896     0.0          -0.752462          1.801133     0.581225
# 97    -0.210958     0.0           1.826304         -0.503478     0.583470
# 98     0.310401     1.0           1.826305         -0.488254     2.157281
# 99     0.318895     1.0           1.825018         -0.488254     0.583470
#
#     MaxAbsEStateIndex   Ka_mean
# 0           -0.561770 -0.296741
# 1           -0.514904  0.331234
# 2           -0.470431 -0.296741
# 3            0.694773  0.335115
# 4           -0.410107  0.335148
# ..                ...       ...
# 95          -0.470432 -0.296740
# 96          -0.561761 -0.296734
# 97          -0.470432 -0.296741
# 98           0.694810  0.335159
# 99           0.694805  2.133564
#
# [100 rows x 13 columns]

# %%
#Removing values outside bounds
samples_cleaned3 = samples3[(samples3 >= 0) & (samples3 <= 1)].dropna()
samples_cleaned3
# Out:
# Empty DataFrame
# Columns: [304, 209, SMR_VSA4, PEOE_VSA6, FpDensityMorgan2, MinEStateIndex, VSA_EState1, fr_NH0, MinAbsEStateIndex, FpDensityMorgan1, VSA_EState9, MaxAbsEStateIndex, Ka_mean]
# Index: []

# %%
samples_cleaned.shape, samples_cleaned2.shape, samples_cleaned3.shape
# Out:
# ((0, 13), (14, 13), (0, 13))

# %% [markdown]
# ### Model №4
# Reducing learning rate

# %%
set_seed()
ctgan4 = CTGAN(verbose = True,
               generator_lr = 0.01,
               generator_decay=0.001)
ctgan4.fit(df, categorical_features, epochs = 1000)
# Out:
# Gen. (0.64) | Discrim. (-0.25): 100%|██████████| 1000/1000 [01:38<00:00, 10.10it/s]

# %%
samples4 = ctgan4.sample(100)
samples4
# Out:
#     304  209  SMR_VSA4  PEOE_VSA6  FpDensityMorgan2  MinEStateIndex  \
# 0     1    0  0.166840   0.516800          0.934340        0.924063
# 1     1    1  0.023129   0.492149          0.990831        0.156731
# 2     1    0  0.152794   0.222315          0.240407        0.591650
# 3     1    0  0.272304   0.111253          0.988799        0.707359
# 4     1    0  0.070787  -0.013191          0.725927        0.736396
# ..  ...  ...       ...        ...               ...             ...
# 95    1    0 -0.145494   0.298267          0.774316        0.704559
# 96    1    0  0.183378   0.180700          0.682041        0.788472
# 97    1    0  0.380573  -0.147865          0.670057        0.726469
# 98    0    0  0.449740   0.084305          0.434273        0.927042
# 99    0    1  0.539713   0.206102         -0.034642        0.861508
#
#     VSA_EState1  fr_NH0  MinAbsEStateIndex  FpDensityMorgan1  VSA_EState9  \
# 0      0.115230     0.0           0.303540          0.868763     0.044634
# 1      0.541854     0.5          -0.496774          0.436821     0.184226
# 2      0.095291     0.5          -0.055376          0.680642     0.096820
# 3      0.102791     0.0           0.730033          0.900731     0.292814
# 4      0.108026     1.0           0.802624          0.840863     0.205991
# ..          ...     ...                ...               ...          ...
# 95     0.127255     0.0           0.619479          0.502054     0.065817
# 96     0.111984     0.0           0.097095          1.075667     0.174143
# 97     0.105954     0.5           0.793279          0.695490     0.154622
# 98     0.077887     1.0           0.577969          0.368898     0.824018
# 99     0.177242     1.0           0.932306          0.064979     0.428468
#
#     MaxAbsEStateIndex   Ka_mean
# 0            0.425731  0.062495
# 1            0.527912 -0.056538
# 2            0.162166 -0.006203
# 3           -0.032154 -0.039274
# 4            0.025358  0.221583
# ..                ...       ...
# 95           0.078016 -0.031004
# 96           0.573029  0.101135
# 97           0.122458 -0.045422
# 98          -0.152577  0.142092
# 99           0.031897  0.759755
#
# [100 rows x 13 columns]

# %%
#Removing values outside bounds
samples_cleaned4 = samples4[(samples4 >= 0) & (samples4 <= 1)].dropna()
samples_cleaned4
# Out:
#     304  209  SMR_VSA4  PEOE_VSA6  FpDensityMorgan2  MinEStateIndex  \
# 0     1    0  0.166840   0.516800          0.934340        0.924063
# 31    1    0  0.899709   0.568656          0.838236        0.885022
# 44    1    0  0.084128   0.486947          0.740470        0.671071
# 51    1    1  0.042728   0.054424          0.760390        0.836527
# 67    0    1  0.572898   0.067916          0.323032        0.933118
# 73    1    0  0.265522   0.169335          0.760520        0.831713
# 75    0    1  0.736857   0.313704          0.440062        0.951355
#
#     VSA_EState1  fr_NH0  MinAbsEStateIndex  FpDensityMorgan1  VSA_EState9  \
# 0      0.115230     0.0           0.303540          0.868763     0.044634
# 31     0.068079     0.5           0.022493          0.418153     0.248705
# 44     0.111947     0.5           0.189790          0.533480     0.214426
# 51     0.081545     0.0           0.009242          0.847627     0.138214
# 67     0.067044     1.0           0.959764          0.171837     0.432717
# 73     0.114868     0.0           0.176647          0.687432     0.271206
# 75     0.155008     1.0           0.983930          0.079248     0.715091
#
#     MaxAbsEStateIndex   Ka_mean
# 0            0.425731  0.062495
# 31           0.406082  0.005616
# 44           0.561639  0.030148
# 51           0.629822  0.141598
# 67           0.241767  0.376166
# 73           0.180135  0.124850
# 75           0.013153  0.837038

# %%
samples_cleaned.shape, samples_cleaned2.shape, samples_cleaned3.shape, samples_cleaned4.shape
# Out:
# ((0, 13), (14, 13), (0, 13), (7, 13))

# %% [markdown]
# Seems like the second one is the best option

# %% [markdown]
# # Saving Dataset №2

# %% [markdown]
# Generating more samples

# %%
set_seed()
samples22 = ctgan2.sample(200)

#Removing values outside bounds
samples_cleaned22 = samples22[(samples22 >= 0) & (samples22 <= 1)].dropna()
samples_cleaned22
# Out:
#      304  209  SMR_VSA4  PEOE_VSA6  FpDensityMorgan2  MinEStateIndex  \
# 19     0    1  0.240064   0.670673          0.185592        0.868298
# 22     0    0  0.043664   0.587601          0.214587        0.897492
# 32     1    0  0.027317   0.238534          0.283821        0.981707
# 40     1    0  0.204625   0.139349          0.530911        0.806664
# 41     1    0  0.016247   0.307131          0.351850        0.975776
# 42     1    0  0.429687   0.187652          0.930767        0.819096
# 52     1    0  0.418659   0.050735          0.190751        0.926903
# 63     1    0  0.104172   0.076523          0.598996        0.937400
# 65     0    1  0.158000   0.520089          0.317064        0.869948
# 66     1    0  0.050482   0.949786          0.692144        0.759684
# 73     0    0  0.467990   0.071539          0.290464        0.844394
# 79     1    0  0.127919   0.576051          0.617850        0.780724
# 84     0    1  0.528254   0.040352          0.429994        0.994751
# 93     0    1  0.436124   0.432099          0.079933        0.960271
# 105    0    1  0.584925   0.131046          0.234019        0.805324
# 109    1    0  0.020637   0.665654          0.126282        0.786703
# 112    1    0  0.248308   0.032265          0.887309        0.808653
# 118    0    0  0.234943   0.228978          0.675927        0.876678
# 121    1    0  0.354657   0.163690          0.465761        0.987831
# 132    1    0  0.089022   0.160938          0.456868        0.938735
# 134    1    0  0.102824   0.364856          0.375174        0.688076
# 157    1    0  0.123997   0.272323          0.632861        0.732041
# 162    0    1  0.741571   0.062221          0.320372        0.963910
# 165    1    1  0.638873   0.105601          0.367798        0.906745
# 167    1    0  0.337466   0.039408          0.575944        0.739123
# 173    0    1  0.204252   0.326141          0.260137        0.900053
# 182    1    0  0.474960   0.491047          0.619022        0.719560
# 184    0    0  0.213167   0.028645          0.304067        0.962312
# 185    1    1  0.687636   0.352323          0.234295        0.984333
